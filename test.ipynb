# %%
import ultralytics
from ultralytics import YOLO
ultralytics.checks()
# Out:
# /home/pinoc/mlb24/zerobase_dlp/.yolovenv/lib/python3.12/site-packages/torch/cuda/__init__.py:129: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Ultralytics 8.3.24 🚀 Python-3.12.4 torch-2.5.0+cu124 CPU (Intel Xeon Gold 6254 3.10GHz)
# Setup complete ✅ (72 CPUs, 471.8 GB RAM, 454.0/908.9 GB disk)

# %%
model = YOLO("yolo11n.pt")
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 9.03MB/s]

# %%
from ultralytics import settings

# Update a setting
settings.update({"runs_dir": "./YOLODataset/"})

# %%
results = model.train(data="./YOLODataset/dataset.yaml", epochs=2, imgsz=320)
# Out:
# Ultralytics 8.3.24 🚀 Python-3.12.4 torch-2.5.0+cu124 CPU (Intel Xeon Gold 6254 3.10GHz)
# ...

# %%
import glob
files = glob.glob('./YOLODataset/images/test/*.*')

model.predict(files, save=True, imgsz=320, conf=0.3)
# Out:
# 0: 320x320 2 potatos, 8.1ms
# 1: 320x320 (no detections), 8.1ms
# 2: 320x320 (no detections), 8.1ms
# 3: 320x320 1 potato, 1 tomato, 8.1ms
# 4: 320x320 (no detections), 8.1ms
# 5: 320x320 3 potatos, 8.1ms
# 6: 320x320 (no detections), 8.1ms
# 7: 320x320 3 potatos, 8.1ms
# 8: 320x320 (no detections), 8.1ms
# 9: 320x320 (no detections), 8.1ms
# 10: 320x320 (no detections), 8.1ms
# 11: 320x320 (no detections), 8.1ms
# 12: 320x320 5 potatos, 8.1ms
# 13: 320x320 (no detections), 8.1ms
# 14: 320x320 1 tomato, 8.1ms
# 15: 320x320 2 potatos, 8.1ms
# 16: 320x320 5 potatos, 8.1ms
# 17: 320x320 (no detections), 8.1ms
# 18: 320x320 (no detections), 8.1ms
# 19: 320x320 1 potato, 8.1ms
# 20: 320x320 (no detections), 8.1ms
# 21: 320x320 2 potatos, 2 tomatos, 8.1ms
# 22: 320x320 (no detections), 8.1ms
# 23: 320x320 (no detections), 8.1ms
# 24: 320x320 (no detections), 8.1ms
# 25: 320x320 (no detections), 8.1ms
# 26: 320x320 (no detections), 8.1ms
# 27: 320x320 (no detections), 8.1ms
# ...
